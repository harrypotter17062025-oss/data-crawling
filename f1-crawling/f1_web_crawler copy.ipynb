# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "YOUR_URL_HERE"
response = requests.get("https://www.formula1.com/en/results/2026/drivers.html")

data = []

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    # Extract data from the soup object as neededs
    table = soup.find('table', class_='Table-module_table__cKsW2')
    rows = table.find_all('tr')
    
    for row in rows[1:]:  # Skip the header row
        columns = row.find_all('td')
        if len(columns) > 1:  # Ensure there are enough columns
            position = columns[0].text.strip()
            driver_name = columns[1].text.strip()
            team = columns[2].text.strip()
            points = columns[3].text.strip()
            print(f'Position: {position}, Driver: {driver_name}, Team: {team}, Points: {points}')

# 👉 tạo DataFrame
df = pd.DataFrame(data, columns=["Position", "Driver", "Team", "Points"])

# 👉 lưu Excel
df.to_excel("data.xlsx", index=False)

df
# Out:
# Empty DataFrame
# Columns: [Position, Driver, Team, Points]
# Index: []
