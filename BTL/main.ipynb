# %%
# ==============================
# 1. IMPORT THƯ VIỆN
# ==============================
import pandas as pd
import matplotlib.pyplot as plt

# ==============================
# 2. ĐỌC FILE EXCEL
# ==============================
file = "MAT16A_Du_lieu_Tai_chinh_cong_Viet_Nam_2005_2020.xlsx"

# Xem tên các sheet
xls = pd.ExcelFile(file)
print("Danh sách sheet:", xls.sheet_names)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Danh sách sheet: ['Hướng dẫn', 'Dashboard', 'Data_2005_2020', 'Mô tả biến', 'Thống kê mô tả', 'Tương quan', 'Hồi quy OLS', 'Nguồn dữ liệu']

# %%
# ===============================
# 3. Xay dung dashboard
# ===============================

# Đọc dữ liệu từ sheet "Data_2005_2020"
df_master_data = pd.read_excel(file, sheet_name="Data_2005_2020", header=6)
print("Dữ liệu Data goc:",df_master_data);

# Doc du lieu tang truong GDP
df_gdp = df_master_data["GDP_Growth"]
print(df_gdp)
# Out:
# Dữ liệu Data goc:    Dữ liệu tài chính công Việt Nam giai đoạn 2005–2020  \
# 0   Đơn vị chính: %, tỷ USD; các cột có chú thích,...
# 1                                                 NaN
# 2                                                Year
# 3                                        Năm quan sát
# 4                                                 Năm
# 5                                                 NaN
# 6                                                Year
# 7                                                2005
# 8                                                2006
# 9                                                2007
# 10                                               2008
# 11                                               2009
# 12                                               2010
# 13                                               2011
# 14                                               2012
# 15                                               2013
# ...
